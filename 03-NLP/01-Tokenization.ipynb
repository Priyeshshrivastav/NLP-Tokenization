# %%
import nltk
print("hello")
# Out:
# hello

# %%
corpus='''Hello welcome ,to Priyesh Shrivastav NLP.Tutorials.
please do watch the entire course to expert in NLP'''

# %%
print(corpus)
# Out:
# Hello welcome ,to Priyesh Shrivastav NLP.Tutorials.
# please do watch the entire course to expert in NLP

# %%
## Tokenizations
##Paragraph->Sentences

from nltk.tokenize import sent_tokenize
sentences=sent_tokenize(corpus)

# %%
# sent_tokenize(corpus)
print(sentences)
# Out:
# ['Hello welcome ,to Priyesh Shrivastav NLP.Tutorials.', 'please do watch the entire course to expert in NLP']

# %%
## Tokenization
## Paragraph-->Words
## sentences-->Words
from nltk.tokenize import word_tokenize
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Priyesh',
#  'Shrivastav',
#  'NLP.Tutorials',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'expert',
#  'in',
#  'NLP']

# %%
for sentence in corpus:
    print(word_tokenize(sentence))
# Out:
# ['H']
# ['e']
# ['l']
# ['l']
# ['o']
# []
# ['w']
# ['e']
# ['l']
# ['c']
# ['o']
# ['m']
# ['e']
# []
# [',']
# ['t']
# ['o']
# []
# ['P']
# ['r']
# ['i']
# ['y']
# ['e']
# ['s']
# ['h']
# []
# ['S']
# ['h']
# ['r']
# ['i']
# ['v']
# ['a']
# ['s']
# ['t']
# ['a']
# ['v']
# []
# ['N']
# ['L']
# ['P']
# ['.']
# ['T']
# ['u']
# ['t']
# ['o']
# ['r']
# ['i']
# ['a']
# ['l']
# ['s']
# ['.']
# []
# ['p']
# ['l']
# ['e']
# ['a']
# ['s']
# ['e']
# []
# ['d']
# ['o']
# []
# ['w']
# ['a']
# ['t']
# ['c']
# ['h']
# []
# ['t']
# ['h']
# ['e']
# []
# ['e']
# ['n']
# ['t']
# ['i']
# ['r']
# ['e']
# []
# ['c']
# ['o']
# ['u']
# ['r']
# ['s']
# ['e']
# []
# ['t']
# ['o']
# []
# ['e']
# ['x']
# ['p']
# ['e']
# ['r']
# ['t']
# []
# ['i']
# ['n']
# []
# ['N']
# ['L']
# ['P']

# %%
from nltk.tokenize import wordpunct_tokenize

wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Priyesh',
#  'Shrivastav',
#  'NLP',
#  '.',
#  'Tutorials',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  'to',
#  'expert',
#  'in',
#  'NLP']

# %%
from nltk.tokenize import TreebankWordDetokenizer
tokeizer=TreebankWordDetokenizer()

tokeizer.tokenize(corpus)
# Out:
# 'H e l l o   w e l c o m e  , t o   P r i y e s h   S h r i v a s t a v   N L P . T u t o r i a l s . \n p l e a s e   d o   w a t c h   t h e   e n t i r e   c o u r s e   t o   e x p e r t   i n   N L P'

# %%
## examples 

coupusnew="""hey I am a MERN stack developer .and I am currently 2nd year cse Student at iiit manipur .learning GENAI"""

# %%
## sentences tokenization 
from nltk.tokenize import sent_tokenize
sent_tokenize(coupusnew)
# Out:
# ['hey I am a MERN stack developer .and I am currently 2nd year cse Student at iiit manipur .learning GENAI']

# %%
## word tokenization
from nltk.tokenize import word_tokenize
word_tokenize(coupusnew)
# Out:
# ['hey',
#  'I',
#  'am',
#  'a',
#  'MERN',
#  'stack',
#  'developer',
#  '.and',
#  'I',
#  'am',
#  'currently',
#  '2nd',
#  'year',
#  'cse',
#  'Student',
#  'at',
#  'iiit',
#  'manipur',
#  '.learning',
#  'GENAI']
